# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('training_WeeklyAggregate.csv')
df.head(5)
# Out:
#    sourceid  dstid  dow  mean_travel_time
# 0        10    241    3           2334.43
# 1        10    612    5           1529.83
# 2        10    905    4           1390.04
# 3        10    407    7            157.91
# 4        10    603    4           1781.67

# %%
sns.pairplot(df)

# %%
sns.histplot(df['mean_travel_time'])
# Out:
# <AxesSubplot:xlabel='mean_travel_time', ylabel='Count'>
